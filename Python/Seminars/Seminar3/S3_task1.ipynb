# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./laptop_price.csv', encoding='cp1251')
df.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %% [markdown]
# * Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU

# %%
def nameOfCompanyFunction(CPUname: str):
    nameOfCompanyOutcome = CPUname.split(' ')[0]
    return nameOfCompanyOutcome

# %%
df['Cpu_Company'] = df['Cpu'].apply(nameOfCompanyFunction)

# %%
df['Cpu_Company'].value_counts()
# Out:
# Cpu_Company
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %% [markdown]
# * Создать новый признак Memory_Amount, который будет cодержать только количество Gb памяти без указания типа носителя

# %%
def memorySizeFunction(MemoryColumn: str):
    return int(float(MemoryColumn.split( )[0][:-2]))

# %%
memorySizeFunction('128GB Flash Storage	')
# Out:
# 128

# %%
df['Memory_Amount'] = df['Memory'].apply(memorySizeFunction)

# %%
df['Memory_Amount'].value_counts()
# Out:
# Memory_Amount
# 256    508
# 1      250
# 128    177
# 512    140
# 500    132
# 32      45
# 64      17
# 2       16
# 16      10
# 180      5
# 240      1
# 8        1
# 508      1
# Name: count, dtype: int64

# %% [markdown]
# * Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD/SDD/др.)

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
def memoryTypeFunction(MemoryColumn: str):
    return MemoryColumn.split( )[1]

# %%
memoryTypeFunction('512GB SSD +  1.0TB Hybrid')
# Out:
# 'SSD'

# %%
df['Memory_Type'] = df['Memory'].apply(memoryTypeFunction)

# %%
df['Memory_Type'].value_counts()
# Out:
# Memory_Type
# SSD       843
# HDD       375
# Flash      75
# Hybrid     10
# Name: count, dtype: int64

# %% [markdown]
# * Удалите признаки Memory и ScreenResolution

# %%
df.drop(columns=['Memory','ScreenResolution']) #drop создает копию датафрейма, не меняет текущего
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                                   Cpu   Ram  \
# 0              Ultrabook    13.3                  Intel Core i5 2.3GHz   8GB
# ...

# %%
df.drop(columns=['Memory','ScreenResolution'], inplace=True) #drop затирает при наличии inplace=True

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type
# 0  1.37kg      1339.69       Intel            128         SSD
# 1  1.34kg       898.94       Intel            128       Flash
# ...

# %% [markdown]
# * Создайте признак SSD, который изначально равен 0

# %%
df['SSD'] = 0

# %% [markdown]
# * Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD

# %%
def checkIfSSD(MemoryType: str):
    if MemoryType == 'SSD':
        SSDstatus = 1
    else:
        SSDstatus = 0
    return SSDstatus

# %%
df['SSD'] = df['Memory_Type'].apply(checkIfSSD)

# %%
df.head(2)
# Out:
#    laptop_ID Company      Product   TypeName  Inches                   Cpu  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  Intel Core i5 2.3GHz
# 1          2   Apple  Macbook Air  Ultrabook    13.3  Intel Core i5 1.8GHz
#
#    Ram                           Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1  8GB        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
#
#    Memory_Amount Memory_Type  SSD
# 0            128         SSD    1
# 1            128       Flash    0

# %%
df.drop(columns=['SSD'], inplace=True)

# %%
df['SSD'] = 0
df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1

# %%
df.head(2)
# Out:
#    laptop_ID Company      Product   TypeName  Inches                   Cpu  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  Intel Core i5 2.3GHz
# 1          2   Apple  Macbook Air  Ultrabook    13.3  Intel Core i5 1.8GHz
#
#    Ram                           Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       Intel
# 1  8GB        Intel HD Graphics 6000  macOS  1.34kg       898.94       Intel
#
#    Memory_Amount Memory_Type  SSD
# 0            128         SSD    1
# 1            128       Flash    0

# %% [markdown]
# * Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
def removeKg1(anystr: str):
    return float(anystr.rstrip('kg'))

# %%
def removeKg2(anystr: str):
    return float(anystr.replace('kg', ''))

# %%
df['Weight'] = df['Weight'].apply(removeKg2)

# %% [markdown]
# * Создайте датафрейм с клиентами:
#
# clients = pd.DataFrame({
#  'client_id': [45, 32, 67, 33, 43],
#  'laptop_id': [506, 398, 710, 120, 1999]
# })

# %%
clients = pd.DataFrame({
 'client_id': [45, 32, 67, 33, 43],
 'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
clients
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %% [markdown]
# * Присоедините к таблице clients данные по ноутбукам через метод join

# %%
clients_id = clients.set_index('laptop_id')

# %%
clients_id.join(df)
# Out:
#            client_id  laptop_ID Company                 Product     TypeName  \
# laptop_id
# 506               45      513.0    Asus  ZenBook UX510UX-CN211T     Notebook
# 398               32      405.0    Dell         Precision M5520  Workstation
# 710               67      718.0  Lenovo      Legion Y520-15IKBN       Gaming
# 120               33      123.0    Acer                  Spin 3     Notebook
# 1999              43        NaN     NaN                     NaN          NaN
#
#            Inches                          Cpu  Ram  \
# laptop_id
# 506          15.6   Intel Core i7 7500U 2.7GHz  8GB
# 398          15.6  Intel Core i7 7700HQ 2.8GHz  8GB
# 710          15.6  Intel Core i7 7700HQ 2.8GHz  8GB
# 120          15.6   Intel Core i3 7100U 2.4GHz  6GB
# 1999          NaN                          NaN  NaN
#
#                                   Gpu       OpSys  Weight  Price_euros  \
# laptop_id
# 506             Intel HD Graphics 620  Windows 10    2.00       1224.0
# ...

# %% [markdown]
# * Присоедините к таблице clients данные по ноутбукам через метод merge

# %%
merged = clients.merge(df, left_on='laptop_id', right_index=True, how='left')

# %%
merged
# Out:
#    client_id  laptop_id  laptop_ID Company                 Product  \
# 0         45        506      513.0    Asus  ZenBook UX510UX-CN211T
# 1         32        398      405.0    Dell         Precision M5520
# 2         67        710      718.0  Lenovo      Legion Y520-15IKBN
# 3         33        120      123.0    Acer                  Spin 3
# 4         43       1999        NaN     NaN                     NaN
#
#       TypeName  Inches                          Cpu  Ram  \
# 0     Notebook    15.6   Intel Core i7 7500U 2.7GHz  8GB
# 1  Workstation    15.6  Intel Core i7 7700HQ 2.8GHz  8GB
# 2       Gaming    15.6  Intel Core i7 7700HQ 2.8GHz  8GB
# 3     Notebook    15.6   Intel Core i3 7100U 2.4GHz  6GB
# 4          NaN     NaN                          NaN  NaN
#
#                           Gpu       OpSys  Weight  Price_euros Cpu_Company  \
# 0       Intel HD Graphics 620  Windows 10    2.00       1224.0       Intel
# ...

# %% [markdown]
# * Найдите среднюю стоимость ноутбуков в зависимости от компании производителя

# %%
df.pivot_table(index=['Company'], values=['Price_euros'], aggfunc=['mean']).head()
# Out:
#                 mean
#          Price_euros
# Company
# Acer      626.775825
# Apple    1564.198571
# Asus     1104.169367
# Chuwi     314.296667
# Dell     1186.068990

# %% [markdown]
# * Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.pivot_table(index=['Cpu_Company'], values=['Price_euros'], aggfunc=['mean', 'min', 'max'],sort=False).head()
# Out:
#                     mean         min         max
#              Price_euros Price_euros Price_euros
# Cpu_Company
# Intel        1152.214145       174.0      6099.0
# AMD           560.638871       199.0      2199.0
# Samsung       659.000000       659.0       659.0

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['mean', 'min', 'max']})
# Out:
#              Price_euros
#                     mean    min     max
# Cpu_Company
# AMD           560.638871  199.0  2199.0
# Intel        1152.214145  174.0  6099.0
# Samsung       659.000000  659.0   659.0

# %% [markdown]
# * Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ

# %%
*f.pivot_table(index=['Cpu_Company'], values=['Price_euros'], aggfunc=['count', 'min', 'max'],sort=False).head()
# Out:
#                   count         min         max
#             Price_euros Price_euros Price_euros
# Cpu_Company
# Intel              1240       174.0      6099.0
# AMD                  62       199.0      2199.0
# Samsung               1       659.0       659.0

# %% [markdown]
# * Ноутбуков каких компаний и с каким процессором больше?
# * С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index=df['Company'], columns=df['Cpu_Company'], normalize='index')
# Out:
# Cpu_Company       AMD     Intel   Samsung
# Company
# Acer         0.097087  0.902913  0.000000
# Apple        0.000000  1.000000  0.000000
# Asus         0.069620  0.930380  0.000000
# Chuwi        0.000000  1.000000  0.000000
# Dell         0.000000  1.000000  0.000000
# Fujitsu      0.000000  1.000000  0.000000
# Google       0.000000  1.000000  0.000000
# HP           0.091241  0.908759  0.000000
# Huawei       0.000000  1.000000  0.000000
# LG           0.000000  1.000000  0.000000
# Lenovo       0.053872  0.946128  0.000000
# MSI          0.000000  1.000000  0.000000
# Mediacom     0.000000  1.000000  0.000000
# Microsoft    0.000000  1.000000  0.000000
# Razer        0.000000  1.000000  0.000000
# Samsung      0.000000  0.888889  0.111111
# Toshiba      0.000000  1.000000  0.000000
# Vero         0.000000  1.000000  0.000000
# Xiaomi       0.000000  1.000000  0.000000
